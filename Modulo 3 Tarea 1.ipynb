# %% [markdown]
# ### Modulo 3 Tarea 1 // Ejercicio 1

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('DelayedFlights.csv', index_col=0)
df.head()
# Out:
#    Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  ArrTime  \
# 0  2008      1           3          4   2003.0        1955   2211.0
# 1  2008      1           3          4    754.0         735   1002.0
# 2  2008      1           3          4    628.0         620    804.0
# 4  2008      1           3          4   1829.0        1755   1959.0
# 5  2008      1           3          4   1940.0        1915   2121.0
#
#    CRSArrTime UniqueCarrier  FlightNum  ... TaxiIn  TaxiOut  Cancelled  \
# 0        2225            WN        335  ...    4.0      8.0          0
# 1        1000            WN       3231  ...    5.0     10.0          0
# 2         750            WN        448  ...    3.0     17.0          0
# 4        1925            WN       3920  ...    3.0     10.0          0
# 5        2110            WN        378  ...    4.0     10.0          0
#
#    CancellationCode  Diverted  CarrierDelay WeatherDelay NASDelay  \
# ...

# %%
values_UC = df['UniqueCarrier'].value_counts()

# %% [markdown]
# ### Graficar Variable Categorica

# %%
plt.figure(figsize=(10,10))
y = values_UC
mylabels = y.index
plt.title('UniqueCarrier', fontsize=20)
explode = [0]* len(mylabels)
explode[0] = 0.1
explode[-1]= 0.1
plt.pie(y, labels= mylabels, explode=explode, shadow=True, autopct='%.2f%%', startangle=0)

plt.legend(bbox_to_anchor=(1,1),loc=2,fontsize=12, title="Aerolineas:")
plt.savefig('pieplot_UniqueCarrier.png')
plt.show()

# %% [markdown]
# ### Una variable numerica

# %%
### Vamos a comprobar la distribucion de la data para poder tener una mejor perspectiva.

fig = plt.figure(figsize=(8,8))

sns.boxplot(x=df.ArrDelay, y=df.UniqueCarrier)
plt.title('Box Plot: Total flights in Delays', fontsize=14)
plt.xlabel("Arrival delay in minutes",fontsize=12)


plt.savefig('boxPlot_ArrDelay.png')

plt.show()

# %%
data = df['ArrDelay']


fig,axes = plt.subplots(1, 2, figsize=(15,8))

sns.distplot(data, hist=False, ax = axes[0])
axes[0].set(xlabel ='Delay in minutes', ylabel ='Density',
       title ='Arrival Delay')\


x = df['ArrDelay']
plt.hist(x, bins=40)

plt.title("Arrival Delay",fontsize=20)
plt.xlabel("Delay in minutes", fontsize=14)
plt.ylabel("Numbers of flights", fontsize=14)
plt.xlim(None, df['ArrDelay'].max())
plt.grid(color='g', linestyle='-', linewidth=0.5)

plt.savefig("subplot_arrdelay.png")



plt.show()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
fig = plt.figure(figsize=(10, 8))
sns.histplot(x, kde=True, bins=40)

plt.title('Histogram: flights in delays', fontsize=20)
plt.xlabel("Arrival delay in minutes",fontsize=14)
plt.ylabel("Number of flights",fontsize=14)
plt.grid(color='g', linestyle='-', linewidth=0.5)
plt.savefig('Historigram_Fdelays.png')
plt.show()

# %%
df_2 = pd.read_csv('VuelosDemorados.csv')
df_2.tail(2)
# Out:
#          FlightNum  AirTime  Distance  ArrDelay  CarrierDelay  Cancelled  \
# 1936749       1611     79.0       507      38.0          16.0          0
# 1936750       1612     88.0       692      -1.0           NaN          0
# 1936751       1616     82.0       545      64.0          51.0          0
# 1936752       1620     27.0       151      17.0           0.0          0
# 1936753       1621    120.0       906      25.0           3.0          0
# 1936754       1631     78.0       481      75.0           0.0          0
# 1936755       1631    122.0       689      99.0           1.0          0
# 1936756       1639     89.0       533       9.0           NaN          0
# 1936757       1641    104.0       874      -5.0           NaN          0
#
#         arribos tardios  velocidad media
# 1936749    Arribo Tarde         6.417722
# 1936750      Sin Demora         7.863636
# 1936751    Arribo Tarde         6.646341
# 1936752    Arribo Tarde         5.592593
# ...

# %% [markdown]
# ### Una Variable numerica y una Categorica

# %%
At = df_2['arribos tardios'].value_counts()
At
# Out:
# Arribo Tarde    1723415
# Sin Demora       213343
# Name: arribos tardios, dtype: int64

# %%
plt.figure(figsize=(8,8))
labels = ["Arribos Tardios", "Sin Demora"]
explode = [0, 0.2]
plt.pie(At, labels = labels, autopct='%.2f%%', explode=explode, shadow=True)

plt.title("Porcentaje de arribos tardios",fontsize=20)
plt.legend(title= "Variables:", fontsize=12)
plt.savefig('Pieplot_AT.png')

plt.show()

# %% [markdown]
# ### Dos Variables numericas

# %%
sub_df = df[['ArrDelay', 'DepDelay']]
sub_df = sub_df.sample(10000)

# %%
plt.figure(figsize =(20, 8))

sns.regplot(data=sub_df, x='ArrDelay', y='DepDelay', fit_reg=True, line_kws=dict(color="red"))

plt.title("ARRIVAL DELAY VS DEPARTURE DELAY",fontsize=24)
plt.xlabel("Arrival delay in minutes", fontsize=18)
plt.ylabel("Departure delay in minutes", fontsize=18)
plt.grid(color='g', linestyle='-', linewidth=0.5)

plt.savefig('Scatterplot.png')
plt.show()

# %%
plt.figure(figsize =(12, 8))

sns.set(style="whitegrid")
ax = sns.boxplot(y=df_2["arribos tardios"],
x = df_2["ArrDelay"],
hue= df_2['arribos tardios'],
data=df_2,
palette="Set3")
plt.savefig('boxplot_arribos_Tardios.png')
plt.show()

# %%
plt.figure(figsize =(10, 8))
sns.set(style="whitegrid")
ax = sns.barplot(x=At.values, y=At.index, data=df_2, hue=At.index, palette="Set3")

# %% [markdown]
# ### 3 Variables Numericas

# %%
data = df[["UniqueCarrier","ArrDelay","DepDelay"]]
data = data.groupby("UniqueCarrier")[["ArrDelay","DepDelay"]].sum()
data= data.sort_values(by="ArrDelay", ascending=False)
labels = data.index

# %%
fig, ax = plt.subplots(figsize=(10,8))

ax.bar(data.index, data["ArrDelay"],label="Arrival delay")
ax.bar(data.index, data["DepDelay"], bottom=data["ArrDelay"],label= "Departure delay",color='lime')
ax.set_title("Total Delay by Airline",fontsize=20)
ax.set_ylabel("Total delay in minutes", fontsize=14)
ax.set_xlabel("Airlines code", fontsize=14)

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

ax.yaxis.grid(True)
ax.xaxis.grid(False)

plt.legend(loc="best", title="Variables:")

plt.savefig('stacker_bar.png')

plt.show()

# %%
data = df[["UniqueCarrier","ArrDelay","DepDelay","AirTime"]]
data = data.groupby("UniqueCarrier")[["ArrDelay","DepDelay","AirTime"]].sum()

plt.figure(figsize = (15,10))
ax = sns.scatterplot(data=data, x="ArrDelay", y="DepDelay",\
                    size="AirTime", sizes=(500, 1500),\
                    alpha = 0.5,
                    hue="UniqueCarrier",
                    palette="rainbow",
                    edgecolor="black",
                    )



for line in range(0,data.shape[0]):
     ax.text(data.ArrDelay[line], data.DepDelay[line], data.index[line], \
        horizontalalignment='center', size='small')

plt.legend(title="Size")    
plt.legend(bbox_to_anchor=(1, 1),loc='best', fontsize=11, borderaxespad=2)

plt.title("Arrival & Departure Delay and Air Time by Airline ", fontsize=20)
plt.xlabel("Sum of Arrival delay in minutes", fontsize= 14, color="r")
plt.ylabel("Sum Departure delay in minutes", fontsize= 14, color="r")


ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

ax.yaxis.grid(True)
ax.xaxis.grid(True)
plt.savefig('bubble_chart.png')
plt.show()
